# %%
# install packages if necissary 
# ] add CSV
# ] add DataFrames
# ] add Optim

# %%
using CSV
using DataFrames
using WGLMakie
using Optim

# %%
alldata = CSV.read("data.csv", DataFrame);

# %%
size(alldata)
# Out:
# (20, 6)

# %%
data = alldata[5:end, :];

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)
f
# Out:
# <div data-jscall-id="10">
#   <div id="3d21539b-4fd6-40e4-ba60-ba3be10fe9bd" data-jscall-id="jsserver-application-dom">
#     <script data-jscall-id="3" src="data:application/javascript;base64,..." type="module"></script>
#     <script data-jscall-id="4" src="..." type="module"></script>
#     <script data-jscall-id="5" src="data:application/javascript;base64,..." type="module"></script>
#     <span data-jscall-id="1"></span>
#   </div>
#   <div id="59af9671-cf14-4009-95b4-00c11f40b0be" data-jscall-id="jsserver-application-dom">
#     <script data-jscall-id="9" src="data:application/javascript;base64,..." type="module"></script>
#     <div data-jscall-id="7">
#       <canvas data-jscall-id="6" tabindex="0"></canvas>
#     </div>
#   </div>
# </div>

# %%
b_eye = 50.
m_eye = 2.
# Out:
# 2.0

# %%
xx = LinRange(50, 250, 20)
# Out:
# 20-element LinRange{Float64, Int64}:
#  50.0,60.5263,71.0526,81.5789,92.1053,…,207.895,218.421,228.947,239.474,250.0

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)

yy_eye = xx .* m_eye .+ b_eye
lines!(xx, yy_eye)

f
# Out:
# <div id="863039c8-2f06-415d-bb77-079862135684" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="14" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="12">
#     <canvas data-jscall-id="11" tabindex="0"></canvas>
#   </div>
# </div>

# %%
function objective(parameters)
    b = parameters[1]
    m = parameters[2]
    @show b, m
    return abs(b - 3.4) + abs(m - 17)
end
# Out:
# objective (generic function with 1 method)

# %%
function objective_2(parameters)
    b = parameters[1]
    m = parameters[2]

    y_pred = b .+ m .* data.x
    
    return sum(abs.(data.y .- y_pred))
end
# Out:
# objective_2 (generic function with 1 method)

# %%
starting_params = [b_eye + 0., m_eye]
result = optimize(objective_2, starting_params)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     3.765701e+02
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    97
#     f(x) calls:    190

# %%
b_abs, m_abs = Optim.minimizer(result)
# Out:
# 2-element Vector{Float64}:
#  53.74766339105346
#   2.056074767629348

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)

yy_eye = xx .* m_eye .+ b_eye
lines!(xx, yy_eye, color=:orange)

yy_abs = xx .* m_abs .+ b_abs
lines!(xx, yy_abs, color=:green)

f
# Out:
# <div id="e39a9828-f5ea-4df2-9d87-7e7121a7f41a" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="18" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="16">
#     <canvas data-jscall-id="15" tabindex="0"></canvas>
#   </div>
# </div>

# %% [markdown]
# # Problem 1 - Quadradic Fit
#
# Here we will fit the data to a qadratic model instead of a linear model, we will do this by adding a quadractic term in the objective function as well as a new parameter to optimize.

# %%
function objective_3(parameters)
    b = parameters[1]
    m = parameters[2]
    q = parameters[3]

    y_pred = b .+ m .* data.x .+ q .* data.x.^2
    
    return sum(abs.(data.y .- y_pred))
end
# Out:
# objective_3 (generic function with 1 method)

# %%
b_eye = 50.
m_eye = 2.
q_eye = 0.001
# Out:
# 0.001

# %%
starting_params = [b_eye + 0., m_eye + 0., q_eye + 0.]
result = optimize(objective_3, starting_params)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     3.339365e+02
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    192
#     f(x) calls:    355

# %%
b_abs, m_abs, q_abs = Optim.minimizer(result)
# Out:
# 3-element Vector{Float64}:
#  94.76027385840413
#   1.1092347687349888
#   0.0041332073587093

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)

yy_eye = xx.^2 .*q_eye .+ xx .* m_eye .+ b_eye
lines!(xx, yy_eye, color=:orange)

yy_abs = xx.^2 .*q_abs .+ xx .* m_abs .+ b_abs
lines!(xx, yy_abs, color=:green)

f
# Out:
# <div id="edb28f77-36db-4d26-aad4-25dff04b5d86" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="22" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="20">
#     <canvas data-jscall-id="19" tabindex="0"></canvas>
#   </div>
# </div>

# %%
function objective_gauss(parameters, x, y, sigma)
    b = parameters[1]
    m = parameters[2]

    y_pred = b .+ m .* x
    
    return -sum(
        -log.(sigma * sqrt(2 * π)) .-0.5 .* (y .- y_pred).^2 / sigma.^2)
end
# Out:
# objective_gauss (generic function with 1 method)

# %%
#function shim(p)
#    return objective_abs(p, data.x, data.y, data.sigma_y)
#end

# %%
starting_params = [b_eye + 0., m_eye]
result = optimize(p -> objective_gauss(p, data.x, data.y, data.sigma_y),
                  starting_params)
# Out:
#  * Status: success
#
#  * Candidate solution
#     Final objective value:     1.044426e+03
#
#  * Found with
#     Algorithm:     Nelder-Mead
#
#  * Convergence measures
#     √(Σ(yᵢ-ȳ)²)/n ≤ 1.0e-08
#
#  * Work counters
#     Seconds run:   0  (vs limit Inf)
#     Iterations:    33
#     f(x) calls:    68

# %%
b_gauss, m_gauss = Optim.minimizer(result)
# Out:
# 2-element Vector{Float64}:
#  28.84560565724924
#   2.216646434317286

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)

yy_eye = xx .* m_eye .+ b_eye
lines!(xx, yy_eye, color=:orange)

yy_abs = xx .* m_abs .+ b_abs
lines!(xx, yy_abs, color=:green)

yy_gauss = xx .* m_gauss .+ b_gauss
lines!(xx, yy_gauss, color=:purple, linewidth=3)

f
# Out:
# <div id="33e4c6ec-5ed2-4ba1-819b-4321a91b6383" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="26" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="24">
#     <canvas data-jscall-id="23" tabindex="0"></canvas>
#   </div>
# </div>

# %%
@show data.x;
# Out:
# data.x = [203, 58, 210, 202, 198, 158, 165, 201, 157, 131, 166, 160, 186, 125, 218, 146]

# %%
size(data, 1)
# Out:
# 16

# %%
ndata = size(data,1)

B_jack = zeros(ndata)
M_jack = zeros(ndata)

for i in 1:ndata
    
    xcopy = copy(data.x)
    deleteat!(xcopy, i)

    ycopy = copy(data.y)
    deleteat!(ycopy, i)

    scopy = copy(data.sigma_y)
    deleteat!(scopy, i)

    starting_params = [b_eye + 0., m_eye]
    result = optimize(p -> objective_gauss(p, xcopy, ycopy, scopy),
                      starting_params)
    @assert Optim.converged(result)
    b_jack, m_jack = Optim.minimizer(result)
    
    B_jack[i] = b_jack
    M_jack[i] = m_jack 
end

# %%
@assert 2+2 == 4

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(data.x, data.y, data.sigma_y)
scatter!(data.x, data.y, markersize=20, color=:red)

for i in 1:ndata
    yy_jack = xx .* M_jack[i] .+ B_jack[i]
    lines!(xx, yy_jack, color=:green)
end

yy_gauss = xx .* m_gauss .+ b_gauss
lines!(xx, yy_gauss, color=:purple, linewidth=3)

f
# Out:
# <div id="139fe150-32fe-45c4-ac9f-960d473ecdd7" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="30" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="28">
#     <canvas data-jscall-id="27" tabindex="0"></canvas>
#   </div>
# </div>

# %%
f = Figure()
Axis(f[1, 1])
scatter!(B_jack, M_jack, markersize=20, color=:red)

plot!([b_gauss], [m_gauss], markersize=30)

f
# Out:
# <div id="1cb6a793-da2b-4b37-b220-39b4a19ca577" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="34" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="32">
#     <canvas data-jscall-id="31" tabindex="0"></canvas>
#   </div>
# </div>

# %%
using Statistics

# %%
mean(B_jack), std(B_jack) .* sqrt((ndata - 1) / ndata)
# Out:
# (27.982644701170038, 8.58069162338665)

# %%
mean(M_jack), std(M_jack) .* sqrt((ndata - 1) / ndata)
# Out:
# (2.2212591046386256, 0.04881277590712103)

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(alldata.x, alldata.y, alldata.sigma_y)
scatter!(alldata.x, alldata.y, markersize=20, color=:red)
f
# Out:
# <div id="b2c1a396-e09f-4860-8059-06e3851c88e4" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="38" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="36">
#     <canvas data-jscall-id="35" tabindex="0"></canvas>
#   </div>
# </div>

# %%
starting_params = [b_eye + 0., m_eye]
result = optimize(p -> objective_gauss(p, alldata.x, alldata.y, alldata.sigma_y),
                  starting_params)
@assert Optim.converged(result)
b_bad, m_bad = Optim.minimizer(result)
# Out:
# 2-element Vector{Float64}:
#  310.0184868511828
#    0.6320089810388613

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(alldata.x, alldata.y, alldata.sigma_y)
scatter!(alldata.x, alldata.y, markersize=20, color=:red)

yy_bad = xx .* m_bad .+ b_bad
lines!(xx, yy_bad, color=:purple, linewidth=3)

f
# Out:
# <div id="9cd0b46e-25b6-45fa-8767-eada3fed1a72" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="42" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="40">
#     <canvas data-jscall-id="39" tabindex="0"></canvas>
#   </div>
# </div>

# %%
function objective_outliers(parameters, x, y, sigma)
    b = parameters[1]
    m = parameters[2]

    frac_bad = 0.01
    like_bad = frac_bad * (1. / 600.)

    y_pred = b .+ m .* x
    like_good = (1. - frac_bad) * 1 ./(sqrt(2*π) .* sigma) .* exp.(-0.5 * (y .- y_pred).^2 ./ sigma.^2)
    like = like_bad .+ like_good
    loglike = log.(like)

    return -sum(loglike)
end
# Out:
# objective_outliers (generic function with 1 method)

# %%
starting_params = [b_eye + 0., m_eye]
result = optimize(p -> objective_outliers(p, alldata.x, alldata.y, alldata.sigma_y),
                  starting_params)
@assert Optim.converged(result)
b_out, m_out = Optim.minimizer(result)
# Out:
# 2-element Vector{Float64}:
#  32.71335736732801
#   2.252659398988028

# %%
starting_params = [700 + 0., -0.5]
result = optimize(p -> objective_outliers(p, alldata.x, alldata.y, alldata.sigma_y),
                  starting_params)
@assert Optim.converged(result)
b_punk, m_punk = Optim.minimizer(result)
# Out:
# 2-element Vector{Float64}:
#  627.9728284643311
#   -0.7590088958472745

# %%
f = Figure()
Axis(f[1, 1])
errorbars!(alldata.x, alldata.y, alldata.sigma_y)
scatter!(alldata.x, alldata.y, markersize=20, color=:red)

yy_bad = xx .* m_bad .+ b_bad
lines!(xx, yy_bad, color=:purple, linewidth=3)

yy_out = xx .* m_out .+ b_out
lines!(xx, yy_out, color=:green, linewidth=3)

yy_punk = xx .* m_punk .+ b_punk
lines!(xx, yy_punk, color=:blue, linewidth=3)

f
# Out:
# <div id="0cfd14ef-ff93-4cb8-aeb9-bb84998d20a1" data-jscall-id="jsserver-application-dom">
#   <script data-jscall-id="46" src="data:application/javascript;base64,..." type="module"></script>
#   <div data-jscall-id="44">
#     <canvas data-jscall-id="43" tabindex="0"></canvas>
#   </div>
# </div>
